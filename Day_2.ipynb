# %%
import pandas as pd

# %%
df=pd.read_csv("TCGA-LAML.star_counts.tsv.gz",sep="\t")

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of                Ensembl_ID  TCGA-AB-2987-03A  TCGA-AB-2857-03A  \
# 0      ENSG00000000003.15          4.857981          6.321928
# 1       ENSG00000000005.6          1.584963          1.000000
# 2      ENSG00000000419.13          9.759888          9.992938
# 3      ENSG00000000457.14          8.960002          9.586840
# 4      ENSG00000000460.17          7.965784          9.984418
# ...                   ...               ...               ...
# 60655   ENSG00000288669.1          0.000000          0.000000
# 60656   ENSG00000288670.1          6.459432          7.467606
# 60657   ENSG00000288671.1          0.000000          0.000000
# 60658   ENSG00000288674.1          3.169925          2.584963
# 60659   ENSG00000288675.1          3.000000          3.459432
#
#        TCGA-AB-2847-03A  TCGA-AB-3000-03A  TCGA-AB-2870-03A  TCGA-AB-2826-03A  \
# 0              5.044394          2.807355          2.000000          0.000000
# ...

# %%
print(df.isnull)
# Out:
# <bound method DataFrame.isnull of                Ensembl_ID  TCGA-AB-2987-03A  TCGA-AB-2857-03A  \
# 0      ENSG00000000003.15          4.857981          6.321928
# 1       ENSG00000000005.6          1.584963          1.000000
# 2      ENSG00000000419.13          9.759888          9.992938
# 3      ENSG00000000457.14          8.960002          9.586840
# 4      ENSG00000000460.17          7.965784          9.984418
# ...                   ...               ...               ...
# 60655   ENSG00000288669.1          0.000000          0.000000
# 60656   ENSG00000288670.1          6.459432          7.467606
# 60657   ENSG00000288671.1          0.000000          0.000000
# 60658   ENSG00000288674.1          3.169925          2.584963
# 60659   ENSG00000288675.1          3.000000          3.459432
#
#        TCGA-AB-2847-03A  TCGA-AB-3000-03A  TCGA-AB-2870-03A  TCGA-AB-2826-03A  \
# 0              5.044394          2.807355          2.000000          0.000000
# ...

# %%
import pandas as pd
df = pd.read_csv("TCGA-LAML.star_counts.tsv.gz",sep="\t")
df = df.dropna()

# %%
print((df == 0).sum().sum())
# Out:
# 3462060
